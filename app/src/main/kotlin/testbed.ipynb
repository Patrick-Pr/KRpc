// %%
import com.example.html.html

html {
    head {
        title { +"Html Test" }
    }
    body {
        p { +"Hello World!" }
        p { +"Hello World!" }
        a("link") { +"Kotling"}
        p {
            +"some text"
        }
    }
}
// Out:
// <html>
//   <head>
//     <title>
//       Html Test
//     </title>
//   </head>
//   <body>
//     <p>
//       Hello World!
//     </p>
//     <p>
//       Hello World!
//     </p>
//     <a href="link">
//       Kotling
//     </a>
//     <p>
//       some text
//     </p>
//   </body>
// </html>

// %%
root {
    get {
        Endpoint.Get()
    }
}

// %%
import kotlin.reflect.KClass
import kotlin.reflect.KType
import kotlin.reflect.typeOf

val test: KType = typeOf<List<String>>()

val klass = test.classifier as? KClass<*>
println(klass)
println(klass?.simpleName)
println(test.arguments)
println(test.toString())

val str = if (test.arguments.isEmpty()) """
fun doSomething(arg: ${klass?.simpleName}) {
    println(arg)
}
""".trimMargin()
else """
fun doSomething(arg: ${klass?.simpleName}<${test.arguments.map { (it.type?.classifier as? KClass<*>)?.simpleName }.joinToString(separator = ", ")}>) {
    println(arg)
}
""".trimMargin()

println(str)
// Out:
// class kotlin.collections.List
// List
// [kotlin.String]
// kotlin.collections.List<kotlin.String>
// fun doSomething(arg: List<String>) {
//     println(arg)
// }

// %%
fun doSomething(arg: kotlin.collections.List<kotlin.String>) {
    println(arg)
}

doSomething("fslkdjfsld")
// Out:
// fslkdjfsld
